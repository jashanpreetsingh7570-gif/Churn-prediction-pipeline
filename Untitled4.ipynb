# %% [markdown]
# <a href="https://colab.research.google.com/github/jashanpreetsingh7570-gif/Churn-prediction-pipeline/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec7ee3df-451b-4b4a-8d05-52e9164dd049" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec7ee3df-451b-4b4a-8d05-52e9164dd049">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

for file_name in os.listdir('.'):
    if file_name.endswith('.zip'):
        with zipfile.ZipFile(file_name, 'r') as zip_ref:
            zip_ref.extractall('./')
        print(f"Extracted {file_name} successfully!")
# Out:
# Extracted archive (1).zip successfully!

# %%
import numpy as np
import pandas as pd
from typing import Tuple, Dict
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier


class ChurnPredictionPipeline:

    def __init__(self, data_path: str):
        self.data_path = data_path
        self.raw_df = None
        self.preprocessor = None
        self.best_model = None

    def load_and_clean_data(self) -> Tuple[pd.DataFrame, pd.Series]:
        self.raw_df = pd.read_csv(self.data_path)

        df = self.raw_df.drop(columns=["customerID"])

        df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
        df["TotalCharges"].fillna(df["TotalCharges"].median(), inplace=True)

        df["Churn"] = df["Churn"].map({"Yes": 1, "No": 0})

        features = df.drop(columns=["Churn"])
        target = df["Churn"]

        return features, target

    def build_preprocessor(self, X: pd.DataFrame) -> ColumnTransformer:
        numeric_features = X.select_dtypes(
            include=["int64", "float64"]
        ).columns.tolist()
        categorical_features = X.select_dtypes(
            include=["object"]
        ).columns.tolist()

        self.preprocessor = ColumnTransformer(
            transformers=[
                ("num", StandardScaler(), numeric_features),
                (
                    "cat",
                    OneHotEncoder(drop="first", handle_unknown="ignore"),
                    categorical_features,
                ),
            ]
        )
        return self.preprocessor

    def evaluate_baselines(
        self, X_train: pd.DataFrame, X_test: pd.DataFrame, y_train: pd.Series, y_test: pd.Series
    ) -> pd.DataFrame:
        candidate_models = {
            "Logistic Regression": LogisticRegression(
                max_iter=1000, random_state=42
            ),
            "Random Forest": RandomForestClassifier(
                n_estimators=100, random_state=42
            ),
            "Gradient Boosting": GradientBoostingClassifier(random_state=42),
        }

        results = {}

        for name, classifier in candidate_models.items():
            model_pipeline = Pipeline(
                steps=[
                    ("preprocessor", self.preprocessor),
                    ("classifier", classifier),
                ]
            )

            model_pipeline.fit(X_train, y_train)
            predictions = model_pipeline.predict(X_test)
            probabilities = model_pipeline.predict_proba(X_test)[:, 1]

            results[name] = {
                "Accuracy": accuracy_score(y_test, predictions),
                "Precision": precision_score(y_test, predictions),
                "Recall": recall_score(y_test, predictions),
                "F1-Score": f1_score(y_test, predictions),
                "ROC-AUC": roc_auc_score(y_test, probabilities),
            }

        return pd.DataFrame(results).T

    def optimize_best_model(
        self, X_train: pd.DataFrame, y_train: pd.Series
    ) -> GridSearchCV:
        tuning_pipeline = Pipeline(
            steps=[
                ("preprocessor", self.preprocessor),
                ("classifier", GradientBoostingClassifier(random_state=42)),
            ]
        )

        search_space = {
            "classifier__n_estimators": [100, 150],
            "classifier__learning_rate": [0.05, 0.1],
            "classifier__max_depth": [3, 4],
        }

        grid_search = GridSearchCV(
            tuning_pipeline,
            param_grid=search_space,
            cv=5,
            scoring="f1",
            n_jobs=-1,
        )
        grid_search.fit(X_train, y_train)
        self.best_model = grid_search.best_estimator_

        return grid_search


if __name__ == "__main__":
    pipeline_manager = ChurnPredictionPipeline(
        "WA_Fn-UseC_-Telco-Customer-Churn.csv"
    )

    X, y = pipeline_manager.load_and_clean_data()

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.20, random_state=42, stratify=y
    )

    pipeline_manager.build_preprocessor(X_train)

    benchmark_df = pipeline_manager.evaluate_baselines(
        X_train, X_test, y_train, y_test
    )
    print("--- Model Benchmarks ---")
    print(benchmark_df.round(4))

    print("\nTuning best estimator...")
    optimizer = pipeline_manager.optimize_best_model(X_train, y_train)
    print(f"Optimal Parameters: {optimizer.best_params_}")
# Out:
# /tmp/ipykernel_976/1805060410.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["TotalCharges"].fillna(df["TotalCharges"].median(), inplace=True)
# --- Model Benchmarks ---
#                      Accuracy  Precision  Recall  F1-Score  ROC-AUC
# Logistic Regression    0.8055     0.6572  0.5588    0.6040   0.8420
# Random Forest          0.7857     0.6216  0.4920    0.5493   0.8246
# Gradient Boosting      0.7984     0.6531  0.5134    0.5749   0.8421
#
# Tuning best estimator...
# ...

# %%
best_model = optimizer.best_estimator_

predictions = best_model.predict(X_test)
probabilities = best_model.predict_proba(X_test)[:, 1]

ohe_features = best_model.named_steps["preprocessor"].named_transformers_["cat"].get_feature_names_out()
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
all_feature_names = numeric_features + list(ohe_features)

feature_importances = best_model.named_steps["classifier"].feature_importances_

importance_df = pd.DataFrame({
    "Feature": all_feature_names,
    "Importance": feature_importances
}).sort_values(by="Importance", ascending=False)

print("--- Top 10 Churn Drivers ---")
print(importance_df.head(10).to_string(index=False))
# Out:
# --- Top 10 Churn Drivers ---
#                        Feature  Importance
#                         tenure    0.291531
#    InternetService_Fiber optic    0.192732
# PaymentMethod_Electronic check    0.125032
#              Contract_Two year    0.074660
#                   TotalCharges    0.070526
#              Contract_One year    0.059233
#                 MonthlyCharges    0.054645
#           PaperlessBilling_Yes    0.023136
#             OnlineSecurity_Yes    0.015338
#                TechSupport_Yes    0.011876

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

cm = confusion_matrix(y_test, predictions)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=axes[0], cbar=False)
axes[0].set_title("Confusion Matrix")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Actual")

fpr, tpr, _ = roc_curve(y_test, probabilities)
axes[1].plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc_score(y_test, probabilities):.4f})", color="darkorange", lw=2)
axes[1].plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
axes[1].set_title("Receiver Operating Characteristic (ROC) Curve")
axes[1].set_xlabel("False Positive Rate")
axes[1].set_ylabel("True Positive Rate")
axes[1].legend(loc="lower right")

plt.tight_layout()
plt.show()

# %%
sample_customer = X_test.iloc[[0]].copy()

predicted_class = best_model.predict(sample_customer)[0]
churn_probability = best_model.predict_proba(sample_customer)[0][1]

status = "High Risk (Will Churn)" if predicted_class == 1 else "Low Risk (Will Stay)"

print(f"Prediction for Sample Customer:")
print(f"Status: {status}")
print(f"Churn Probability: {churn_probability * 100:.2f}%")
# Out:
# Prediction for Sample Customer:
# Status: Low Risk (Will Stay)
# Churn Probability: 2.23%

# %%
import joblib

joblib.dump(best_model, "churn_prediction_model.pkl")

print("Model successfully exported as 'churn_prediction_model.pkl'")
# Out:
# Model successfully exported as 'churn_prediction_model.pkl'

# %%
import joblib

loaded_model = joblib.load("churn_prediction_model.pkl")

new_predictions = loaded_model.predict(X_test.iloc[:5])
new_probabilities = loaded_model.predict_proba(X_test.iloc[:5])[:, 1]

for i, (pred, prob) in enumerate(zip(new_predictions, new_probabilities), 1):
    risk_label = "Churn" if pred == 1 else "Stay"
    print(f"Customer {i}: {risk_label} ({prob * 100:.2f}% probability)")
# Out:
# Customer 1: Stay (2.23% probability)
# Customer 2: Churn (82.83% probability)
# Customer 3: Stay (5.52% probability)
# Customer 4: Stay (34.81% probability)
# Customer 5: Stay (2.10% probability)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# --- Churn class balance ---
plt.figure(figsize=(5, 4))
sns.countplot(x=y.map({0: "No", 1: "Yes"}), palette="Set2")
plt.title("Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Count")
plt.show()

# --- Numeric features vs churn (tenure, MonthlyCharges, TotalCharges) ---
df_viz = X.copy()
df_viz["Churn"] = y.map({0: "No", 1: "Yes"})

numeric_cols = ["tenure", "MonthlyCharges", "TotalCharges"]
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
for ax, col in zip(axes, numeric_cols):
    sns.kdeplot(data=df_viz, x=col, hue="Churn", fill=True, ax=ax, common_norm=False)
    ax.set_title(f"{col} by Churn")
plt.tight_layout()
plt.show()

# --- Correlation heatmap (numeric features) ---
plt.figure(figsize=(6, 5))
corr = df_viz[numeric_cols + ["SeniorCitizen"]].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", square=True)
plt.title("Correlation Heatmap (Numeric Features)")
plt.show()
# Out:
# /tmp/ipykernel_976/2649186611.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y.map({0: "No", 1: "Yes"}), palette="Set2")

# %%
categorical_cols = ["Contract", "InternetService", "PaymentMethod", "TechSupport", "OnlineSecurity"]

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()
for ax, col in zip(axes, categorical_cols):
    churn_rate = df_viz.groupby(col)["Churn"].apply(lambda s: (s == "Yes").mean())
    churn_rate.sort_values(ascending=False).plot(kind="bar", ax=ax, color="salmon")
    ax.set_title(f"Churn Rate by {col}")
    ax.set_ylabel("Churn Rate")
    ax.tick_params(axis="x", rotation=45)
fig.delaxes(axes[-1])
plt.tight_layout()
plt.show()
